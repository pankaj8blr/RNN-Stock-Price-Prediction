# %% [markdown]
# <a href="https://colab.research.google.com/github/pankaj8blr/RNN-Stock-Price-Prediction/blob/master/Copy_of_RNN_Assg_Stock_Price_Prediction_Starter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Stock Price Prediction Using RNNs

# %% [markdown]
# ## Objective
# The objective of this assignment is to try and predict the stock prices using historical data from four companies IBM (IBM), Google (GOOGL), Amazon (AMZN), and Microsoft (MSFT).
#
# We use four different companies because they belong to the same sector: Technology. Using data from all four companies may improve the performance of the model. This way, we can capture the broader market sentiment.
#
# The problem statement for this assignment can be summarised as follows:
#
# > Given the stock prices of Amazon, Google, IBM, and Microsoft for a set number of days, predict the stock price of these companies after that window.

# %% [markdown]
# ## Business Value
#
# Data related to stock markets lends itself well to modeling using RNNs due to its sequential nature. We can keep track of opening prices, closing prices, highest prices, and so on for a long period of time as these values are generated every working day. The patterns observed in this data can then be used to predict the future direction in which stock prices are expected to move. Analyzing this data can be interesting in itself, but it also has a financial incentive as accurate predictions can lead to massive profits.

# %% [markdown]
# ### **Data Description**
#
# You have been provided with four CSV files corresponding to four stocks: AMZN, GOOGL, IBM, and MSFT. The files contain historical data that were gathered from the websites of the stock markets where these companies are listed: NYSE and NASDAQ. The columns in all four files are identical. Let's take a look at them:
#
# - `Date`: The values in this column specify the date on which the values were recorded. In all four files, the dates range from Jaunary 1, 2006 to January 1, 2018.
#
# - `Open`: The values in this column specify the stock price on a given date when the stock market opens.
#
# - `High`: The values in this column specify the highest stock price achieved by a stock on a given date.
#
# - `Low`: The values in this column specify the lowest stock price achieved by a stock on a given date.
#
# - `Close`: The values in this column specify the stock price on a given date when the stock market closes.
#
# - `Volume`: The values in this column specify the total number of shares traded on a given date.
#
# - `Name`: This column gives the official name of the stock as used in the stock market.
#
# There are 3019 records in each data set. The file names are of the format `\<company_name>_stock_data.csv`.

# %% [markdown]
# ## **1 Data Loading and Preparation** <font color =red> [25 marks] </font>

# %% [markdown]
# #### **Import Necessary Libraries**

# %%
# Import libraries
# !pip install scikit-learn==1.1.3 --upgrade
# !pip install scikeras --upgrade
# Import libraries
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import tensorflow as tf
import itertools
# Fixed import: using the correct module path for train_test_split
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, Dropout
# !pip install scikeras
# from tensorflow.keras.wrappers.scikit_learn import KerasRegressor
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.optimizers import Adam, RMSprop

# Set seaborn style
sns.set(style="whitegrid")
# Out:
# Requirement already satisfied: scikit-learn==1.1.3 in /usr/local/lib/python3.11/dist-packages (1.1.3)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.1.3) (2.0.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.1.3) (1.15.2)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.1.3) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn==1.1.3) (3.6.0)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Collecting scikit-learn>=1.4.2 (from scikeras)
#   Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Using cached scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
# Installing collected packages: scikit-learn
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.1.3
#     Uninstalling scikit-learn-1.1.3:
#       Successfully uninstalled scikit-learn-1.1.3
# Successfully installed scikit-learn-1.6.1
# Requirement already satisfied: scikeras in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from scikeras) (3.8.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from scikeras) (1.6.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.0.9)
# Requirement already satisfied: h5py in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (3.13.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.15.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (0.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from keras>=3.2.0->scikeras) (24.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from optree->keras>=3.2.0->scikeras) (4.13.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)

# %% [markdown]
# ### **1.1 Data Aggregation** <font color =red> [7 marks] </font>

# %% [markdown]
# As we are using the stock data for four different companies, we need to create a new DataFrame that contains the combined data from all four data frames. We will create a function that takes in a list of the file names for the four CSV files, and returns a single data frame. This function performs the following tasks:
# - Extract stock names from file names
# - Read the CSV files as data frames
# - Append the stock names into the columns of their respective data frames
# - Drop unnecessary columns
# - Join the data frames into one.

# %% [markdown]
# #### **1.1.1** <font color =red> [5 marks] </font>
# Create the function to join DataFrames and use it to combine the four datasets.

# %%
# Define a function to load data and aggregate them

def combine_stock_data(file_list):
    dataframes = []

    for file_path in file_list:
        # Extract stock name from filename
        stock_name = os.path.basename(file_path).split('_')[0]

        # Read the CSV
        df = pd.read_csv(file_path)

        # Add a new column for the stock name
        df['Stock'] = stock_name

        # Optionally, drop unnecessary columns
        # (assuming 'Unnamed: 0' or similar)
        if 'Unnamed: 0' in df.columns:
            df = df.drop(columns=['Unnamed: 0'])

        # Append to list
        dataframes.append(df)

    # Combine all dataframes
    combined_df = pd.concat(dataframes, ignore_index=True)
    return combined_df

# %%
# Specify the names of the raw data files to be read and use the aggregation function to read the files

# Example usage
file_list = [
    'https://raw.githubusercontent.com/pankaj8blr/RNN-Stock-Price-Prediction/2eabcaa2d00607cbbbd0cad05ae5d4b212c915e5/RNN_Stocks_Data/AMZN_stocks_data.csv',
    'https://raw.githubusercontent.com/pankaj8blr/RNN-Stock-Price-Prediction/2eabcaa2d00607cbbbd0cad05ae5d4b212c915e5/RNN_Stocks_Data/GOOGL_stocks_data.csv',
    'https://raw.githubusercontent.com/pankaj8blr/RNN-Stock-Price-Prediction/2eabcaa2d00607cbbbd0cad05ae5d4b212c915e5/RNN_Stocks_Data/IBM_stocks_data.csv',
    'https://raw.githubusercontent.com/pankaj8blr/RNN-Stock-Price-Prediction/2eabcaa2d00607cbbbd0cad05ae5d4b212c915e5/RNN_Stocks_Data/MSFT_stocks_data.csv'
]

combined_data = combine_stock_data(file_list)

# Display the combined DataFrame
print(combined_data.head())
# Out:
#          Date   Open   High    Low  Close   Volume  Name Stock
# 0  2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN  AMZN
# 1  2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN  AMZN
# 2  2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN  AMZN
# 3  2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN  AMZN
# 4  2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN  AMZN

# %% [markdown]
# ### View specifics of the data ###

# %%
# View specifics of the data
print(f"Shape of combined data: {combined_data.shape}")


print("Column names:")
print(combined_data.columns.tolist())


print("First 5 rows:")
print(combined_data.head())


print("Data types and missing values:")
print(combined_data.info())


print("Statistical Summary:")
print(combined_data.describe())
# Out:
# Shape of combined data: (12077, 8)
# Column names:
# ['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Name', 'Stock']
# First 5 rows:
#          Date   Open   High    Low  Close   Volume  Name Stock
# 0  2006-01-03  47.47  47.85  46.25  47.58  7582127  AMZN  AMZN
# 1  2006-01-04  47.48  47.73  46.69  47.25  7440914  AMZN  AMZN
# 2  2006-01-05  47.16  48.20  47.11  47.65  5417258  AMZN  AMZN
# 3  2006-01-06  47.97  48.58  47.32  47.87  6154285  AMZN  AMZN
# 4  2006-01-09  46.55  47.10  46.40  47.08  8945056  AMZN  AMZN
# Data types and missing values:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12077 entries, 0 to 12076
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    12077 non-null  object
#  1   Open    12076 non-null  float64
#  2   High    12077 non-null  float64
#  3   Low     12076 non-null  float64
#  4   Close   12077 non-null  float64
#  5   Volume  12077 non-null  int64
#  6   Name    12077 non-null  object
#  7   Stock   12077 non-null  object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 754.9+ KB
# None
# Statistical Summary:
#                Open          High           Low         Close        Volume
# count  12076.000000  12077.000000  12076.000000  12077.000000  1.207700e+04
# mean     227.387118    229.422254    225.203189    227.380960  1.671763e+07
# std      236.938260    238.568485    234.981015    236.851101  2.570572e+07
# min       15.200000     15.620000     14.870000     15.150000  2.542560e+05
# 25%       54.930000     55.660000     54.425000     55.210000  3.124704e+06
# 50%      158.795000    160.410000    157.355000    158.880000  5.445269e+06
# 75%      281.405000    284.500000    278.610000    281.510000  1.802087e+07
# max     1204.880000   1213.410000   1191.150000   1195.830000  5.910786e+08

# %% [markdown]
# #### Summary ####
# - Shape: 12,077 rows × 8 columns
#
# - Columns:
#     - Date (object/string)
#     - Open (float)
#     - High (float)
#     - Low (float)
#     - Close (float)
#     - Volume (int)
#     - Name (object/string) — seems to repeat the stock name
#     - Stock (object/string) — the one we added for stock identity
# - Data Types & Nulls:
#     - No major missing data (Open and Low have only 1 missing value out of 12077 rows).
#     - All numeric columns are floats/ints.
#     - Date, Name, and Stock are strings (object dtype).
# - Observations:
#     - Stock prices range widely (from ~$15 up to $1200+), which makes sense because you have  companies like Amazon and Google here.
#     - Volume is huge for some days — up to nearly 600 million

# %% [markdown]
# #### **1.1.2** <font color =red> [2 marks] </font>
# Identify and handle any missing values.

# %%
# Handle Missing Values

combined_data.isnull().sum()
# Out:
# Date      0
# Open      1
# High      0
# Low       1
# Close     0
# Volume    0
# Name      0
# Stock     0
# dtype: int64

# %%
combined_data.fillna(method='ffill')
# Out:
# <ipython-input-6-199af66212a4>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   combined_data.fillna(method='ffill')
#              Date   Open   High    Low  Close    Volume  Name Stock
# 0      2006-01-03  47.47  47.85  46.25  47.58   7582127  AMZN  AMZN
# 1      2006-01-04  47.48  47.73  46.69  47.25   7440914  AMZN  AMZN
# 2      2006-01-05  47.16  48.20  47.11  47.65   5417258  AMZN  AMZN
# 3      2006-01-06  47.97  48.58  47.32  47.87   6154285  AMZN  AMZN
# 4      2006-01-09  46.55  47.10  46.40  47.08   8945056  AMZN  AMZN
# ...           ...    ...    ...    ...    ...       ...   ...   ...
# 12072  2017-12-22  85.40  85.63  84.92  85.51  14145841  MSFT  MSFT
# 12073  2017-12-26  85.31  85.53  85.03  85.40   9891237  MSFT  MSFT
# 12074  2017-12-27  85.65  85.98  85.22  85.71  14678025  MSFT  MSFT
# 12075  2017-12-28  85.90  85.93  85.55  85.72  10594344  MSFT  MSFT
# 12076  2017-12-29  85.63  86.05  85.50  85.54  18717406  MSFT  MSFT
#
# [12077 rows x 8 columns]

# %% [markdown]
# ### **1.2 Analysis and Visualisation** <font color =red> [5 marks] </font>

# %% [markdown]
# #### **1.2.1** <font color =red> [2 marks] </font>
# Analyse the frequency distribution of stock volumes of the companies and also see how the volumes vary over time.

# %%
# Convert 'Date' to datetime for time-based plots
combined_data['Date'] = pd.to_datetime(combined_data['Date'])

# %%
# Frequency distribution of volumes
plt.figure(figsize=(12,6))
sns.histplot(combined_data['Volume'], bins=50, kde=True, color='skyblue')
plt.title('Frequency Distribution of Stock Volumes')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()

# %%
unique_stocks = combined_data['Stock'].unique()
num_stocks = len(unique_stocks)

fig, axs = plt.subplots(num_stocks, 1, figsize=(14, num_stocks*4), sharex=True)

for i, stock in enumerate(unique_stocks):
    stock_data = combined_data[combined_data['Stock'] == stock]
    axs[i].plot(stock_data['Date'], stock_data['Volume'], label=stock, color='steelblue')
    axs[i].set_title(f'{stock} Volume Over Time')
    axs[i].set_ylabel('Volume')
    axs[i].legend()

plt.xlabel('Date')
plt.tight_layout()
plt.show()

# %%
g = sns.FacetGrid(combined_data, col="Stock", col_wrap=2, height=4, aspect=1.5)
g.map_dataframe(sns.lineplot, x="Date", y="Volume", color="steelblue")
g.set_axis_labels("Date", "Volume")
g.set_titles("{col_name} Stock")
g.fig.suptitle('Stock Volume Variation Over Time (FacetGrid)', fontsize=16, y=1.05)
plt.tight_layout()
plt.show()

# %%
# Stock volume variation over time
plt.figure(figsize=(14,8))
for stock in combined_data['Stock'].unique():
    stock_data = combined_data[combined_data['Stock'] == stock]
    plt.plot(stock_data['Date'], stock_data['Volume'], label=stock)

plt.title('Stock Volume Variation Over Time')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.legend()
plt.show()

# %% [markdown]
# #### **1.2.2** <font color =red> [3 marks] </font>
# Analyse correlations between features.

# %%
# Analyse correlations

correlation_matrix = combined_data[['Open', 'High', 'Low', 'Close', 'Volume']].corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix of Stock Features')
plt.show()

# Optional: Display correlation matrix as text
print("\nCorrelation Matrix:")
print(correlation_matrix)
# Out:
# Correlation Matrix:
#             Open      High       Low     Close    Volume
# Open    1.000000  0.999945  0.999919  0.999873 -0.420741
# High    0.999945  1.000000  0.999907  0.999935 -0.421083
# Low     0.999919  0.999907  1.000000  0.999945 -0.420673
# Close   0.999873  0.999935  0.999945  1.000000 -0.420875
# Volume -0.420741 -0.421083 -0.420673 -0.420875  1.000000

# %% [markdown]
# ### **1.3 Data Processing** <font color =red> [13 marks] </font>

# %% [markdown]
# Next, we need to process the data so that it is ready to be used in recurrent neural networks. You know RNNs are suitable to work with sequential data where patterns repeat at regular intervals.
#
# For this, we need to execute the following steps:
# 1. Create windows from the master data frame and obtain windowed `X` and corresponding windowed `y` values
# 2. Perform train-test split on the windowed data
# 3. Scale the data sets in an appropriate manner
#
# We will define functions for the above steps that finally return training and testing data sets that are ready to be used in recurrent neural networks.

# %% [markdown]
# **Hint:** If we use a window of size 3, in the first window, the rows `[0, 1, 2]` will be present and will be used to predict the value of `CloseAMZN` in row `3`. In the second window, rows `[1, 2, 3]` will be used to predict `CloseAMZN` in row `4`.

# %% [markdown]
# #### **1.3.1** <font color =red> [3 marks] </font>
# Create a function that returns the windowed `X` and `y` data.

# %% [markdown]
# From the main DataFrame, this function will create windowed DataFrames, and store those as a list of DataFrames.
#
# Controllable parameters will be window size, step size (window stride length) and target names as a list of the names of stocks whose closing values we wish to predict.

# %%
# Define a function that divides the data into windows and generates target variable values for each window

def create_windowed_data(df, stock_names, window_size=10, stride=1):
    """
    Creates windowed X and y for selected stocks.

    Parameters:
        df (DataFrame): Master combined stock data
        stock_names (list): List of stock names to predict
        window_size (int): Length of each input window
        stride (int): Stride to slide windows
    Returns:
        X, y (both numpy arrays)
    """
    X = []
    y = []

    # Filter for selected stocks
    df_selected = df[df['Stock'].isin(stock_names)]

    # Sort by Date to maintain temporal order
    df_selected = df_selected.sort_values(['Stock', 'Date'])

    # Group by Stock so that windows don't mix companies
    for stock, group in df_selected.groupby('Stock'):
        features = group[['Open', 'High', 'Low', 'Close', 'Volume']].values
        target = group['Close'].values

        for i in range(0, len(features) - window_size, stride):
            X.append(features[i:i+window_size])
            y.append(target[i+window_size])  # Target is the Close price *after* the window

    return np.array(X), np.array(y)

# %% [markdown]
# #### **1.3.2** <font color =red> [3 marks] </font>
# Create a function to scale the data.

# %% [markdown]
# Define a function that will scale the data.
#
# For scaling, we have to look at the whole length of data to find max/min values or standard deviations and means. If we scale the whole data at once, this will lead to data leakage in the windows. This is not necessarily a problem if the model is trained on the complete data with cross-validation.
#
# One way to scale when dealing with windowed data is to use the `partial_fit()` method.
# ```
# scaler.partial_fit(window)
# scaler.transform(window)
# ```
# You may use any other suitable way to scale the data properly. Arrive at a reasonable way to scale your data.

# %%
# Define a function that scales the windowed data
# The function takes in the windowed data sets and returns the scaled windows

def split_train_test(X, y, test_size=0.2):
    """
    Splits X and y into training and testing sets.
    """
    return train_test_split(X, y, test_size=test_size, random_state=42, shuffle=False)  # No shuffle because it's time series

# %% [markdown]
# Next, define the main function that will call the windowing and scaling helper functions.
#
# The input parameters for this function are:
# - The joined master data set
# - The names of the stocks that we wish to predict the *Close* prices for
# - The window size
# - The window stride
# - The train-test split ratio
#
# The outputs from this function are the scaled dataframes:
# - *X_train*
# - *y_train*
# - *X_test*
# - *y_test*

# %% [markdown]
# #### **1.3.3** <font color =red> [3 marks] </font>
# Define a function to create windows of `window_size` and split the windowed data in to training and validation sets.

# %% [markdown]
# The function can take arguments such as list of target names, window size, window stride and split ratio. Use the windowing function here to make windows in the data and then perform scaling and train-test split.

# %%
# Define a function to create input and output data points from the master DataFrame

# 2. Train-Test Split
def split_train_test(X, y, test_size=0.2):
    """
    Splits X and y into training and testing sets.
    """
    return train_test_split(X, y, test_size=test_size, random_state=42, shuffle=False)  # No shuffle because it's time series

# 3. Scaling Function
def scale_windowed_data(X_train, X_test):
    """
    Scales windowed data feature-wise.

    Each feature across all windows and timesteps is scaled separately.
    """
    n_timesteps = X_train.shape[1]
    n_features = X_train.shape[2]

    # Reshape to (samples * timesteps, features) for scaling
    X_train_reshaped = X_train.reshape(-1, n_features)
    X_test_reshaped = X_test.reshape(-1, n_features)

    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train_reshaped)
    X_test_scaled = scaler.transform(X_test_reshaped)

    # Reshape back to original 3D form
    X_train_scaled = X_train_scaled.reshape(-1, n_timesteps, n_features)
    X_test_scaled = X_test_scaled.reshape(-1, n_timesteps, n_features)

    return X_train_scaled, X_test_scaled, scaler

# 4. Main Wrapper Function
def prepare_windowed_data(df, stock_names, window_size=10, stride=1, test_size=0.2):
    """
    Full pipeline: Windowing, Train-Test Split, Scaling.

    Returns:
        X_train_scaled, y_train, X_test_scaled, y_test
    """
    # Step 1: Window the data
    X, y = create_windowed_data(df, stock_names, window_size, stride)

    # Step 2: Train-test split
    X_train, X_test, y_train, y_test = split_train_test(X, y, test_size)

    # Step 3: Scale the data
    X_train_scaled, X_test_scaled, scaler = scale_windowed_data(X_train, X_test)

    return X_train_scaled, y_train, X_test_scaled, y_test, scaler

# %%
stock_list = ['AMZN', 'GOOGL', 'IBM', 'MSFT']
window_size = 20
stride = 1
test_size = 0.2

X_train, y_train, X_test, y_test, scaler = prepare_windowed_data(
    combined_data,
    stock_list,
    window_size=window_size,
    stride=stride,
    test_size=test_size
)

print(f"Train X shape: {X_train.shape}")
print(f"Train y shape: {y_train.shape}")
print(f"Test X shape: {X_test.shape}")
print(f"Test y shape: {y_test.shape}")
# Out:
# Train X shape: (9597, 20, 5)
# Train y shape: (9597,)
# Test X shape: (2400, 20, 5)
# Test y shape: (2400,)

# %% [markdown]
# We can now use these helper functions to create our training and testing data sets. But first we need to decide on a length of windows. As we are doing time series prediction, we want to pick a sequence that shows some repetition of patterns.
#
# For selecting a good sequence length, some business understanding will help us. In financial scenarios, we can either work with business days, weeks (which comprise of 5 working days), months, or quarters (comprising of 13 business weeks). Try looking for some patterns for these periods.

# %% [markdown]
# #### **1.3.4** <font color =red> [2 marks] </font>
# Identify an appropriate window size.

# %% [markdown]
# For this, you can use plots to see how target variable is varying with time. Try dividing it into parts by weeks/months/quarters.

# %%
# Checking for patterns in different sequence lengths
# Make sure 'Date' is datetime
combined_data['Date'] = pd.to_datetime(combined_data['Date'])

# Pick one stock to analyze patterns (e.g., AMZN)
# stock_to_analyze = file_list[0]
stock_to_analyze = 'AMZN'
stock_df = combined_data[combined_data['Stock'] == stock_to_analyze].copy()
stock_df.set_index('Date', inplace=True)

# Resampling to Weekly, Monthly, Quarterly Close Price
resampled = {
    'Daily': stock_df['Close'],
    'Weekly': stock_df['Close'].resample('W').mean(),
    'Monthly': stock_df['Close'].resample('M').mean(),
    'Quarterly': stock_df['Close'].resample('Q').mean()
}

# Plot all resolutions
fig, axes = plt.subplots(4, 1, figsize=(14, 12), sharex=True)

for i, (freq, series) in enumerate(resampled.items()):
    axes[i].plot(series.index, series.values, label=f'{freq} Close Price', color='tab:blue')
    axes[i].set_title(f'{stock_to_analyze} Close Price - {freq}')
    axes[i].set_ylabel('Close')
    axes[i].legend(loc='upper left')

axes[-1].set_xlabel('Date')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-18-024f25690fc8>:15: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   'Monthly': stock_df['Close'].resample('M').mean(),
# <ipython-input-18-024f25690fc8>:16: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   'Quarterly': stock_df['Close'].resample('Q').mean()

# %% [markdown]
# #### **1.3.5** <font color =red> [2 marks] </font>
# Call the functions to create testing and training instances of predictor and target features.

# %%
# Create data instances from the master data frame using decided window size and window stride

# Create windowed data function
def create_windowed_data_instances(df, stock_names, window_size=30, stride=1):
    """
    Create data instances (X, y) from master DataFrame using window size and stride.

    Parameters:
    - df: master stock dataframe
    - stock_names: list of stock names to consider
    - window_size: number of timesteps in each input window
    - stride: how much to slide the window forward

    Returns:
    - X: numpy array of windowed input sequences
    - y: numpy array of target close prices
    """
    X = []
    y = []

    # Filter only the required stocks
    df_filtered = df[df['Stock'].isin(stock_names)].copy()

    # Sort data properly
    df_filtered = df_filtered.sort_values(by=['Stock', 'Date'])

    # Group by stock so windows don't cross companies
    for stock, stock_df in df_filtered.groupby('Stock'):
        features = stock_df[['Open', 'High', 'Low', 'Close', 'Volume']].values
        target = stock_df['Close'].values

        for i in range(0, len(features) - window_size, stride):
            X.append(features[i:i+window_size])
            y.append(target[i+window_size])  # Target is the Close price after the window

    return np.array(X), np.array(y)

# -----------------------------------

# Example: Create instances
chosen_stocks = ['AMZN', 'GOOGL', 'IBM', 'MSFT']
window_size = 30  # 30 days window
stride = 1  # move window 1 day at a time

X, y = create_windowed_data_instances(combined_data, chosen_stocks, window_size, stride)

print(f"X shape: {X.shape}")  # (samples, window_size, features)
print(f"y shape: {y.shape}")  # (samples,)
# Out:
# X shape: (11957, 30, 5)
# y shape: (11957,)

# %%
# Check the number of data points generated
print(f"Number of X (input) instances: {X.shape[0]}")
print(f"Number of y (target) instances: {y.shape[0]}")

# Double-check that X and y match
assert X.shape[0] == y.shape[0], "Mismatch between X and y instances!"
# Out:
# Number of X (input) instances: 11957
# Number of y (target) instances: 11957

# %% [markdown]
# **Check if the training and testing datasets are in the proper format to feed into neural networks.**

# %%
# Check if the datasets are compatible inputs to neural networks

# 1. Check shapes
print(f"X shape: {X.shape}")
print(f"y shape: {y.shape}")

# 2. Check missing values
print(f"Any NaN in X? {np.isnan(X).any()}")
print(f"Any NaN in y? {np.isnan(y).any()}")

# 3. Check data types
print(f"X dtype: {X.dtype}")
print(f"y dtype: {y.dtype}")

# 4. Optional: Ensure y is 2D (reshaped if needed)
if len(y.shape) == 1:
    y = y.reshape(-1, 1)
    print(f"y reshaped to: {y.shape}")
# Out:
# X shape: (11957, 30, 5)
# y shape: (11957,)
# Any NaN in X? True
# Any NaN in y? False
# X dtype: float64
# y dtype: float64
# y reshaped to: (11957, 1)

# %% [markdown]
# ## **2 RNN Models** <font color =red> [20 marks] </font>

# %% [markdown]
# In this section, we will:
# - Define a function that creates a simple RNN
# - Tune the RNN for different hyperparameter values
# - View the performance of the optimal model on the test data

# %% [markdown]
# ### **2.1 Simple RNN Model** <font color =red> [10 marks] </font>

# %% [markdown]
# #### **2.1.1** <font color =red> [3 marks] </font>
# Create a function that builds a simple RNN model based on the layer configuration provided.

# %%
# Create a function that creates a simple RNN model according to the model configuration arguments

def create_simple_rnn_model(input_shape,
                             rnn_units=50,
                             dense_units=1,
                             dropout_rate=0.2,
                             optimizer='adam',
                             loss='mse'):
    """
    Function to create a simple RNN model with configurable arguments.

    Parameters:
    - input_shape: tuple, shape of input (timesteps, features)
    - rnn_units: int, number of units in the RNN layer
    - dense_units: int, number of output units (default 1 for regression)
    - dropout_rate: float, dropout rate after RNN
    - optimizer: optimizer to use
    - loss: loss function to use

    Returns:
    - model: compiled RNN model
    """
    model = Sequential()

    # RNN layer
    model.add(SimpleRNN(units=rnn_units, input_shape=input_shape, return_sequences=False))

    # Dropout layer
    model.add(Dropout(rate=dropout_rate))

    # Dense output layer
    model.add(Dense(units=dense_units))

    # Compile the model
    model.compile(optimizer=optimizer, loss=loss, metrics=['mae'])

    return model

# %% [markdown]
# #### **2.1.2** <font color =red> [4 marks] </font>
# Perform hyperparameter tuning to find the optimal network configuration.

# %%
# Manual Grid Search with Keras
# Define Parameter Grid
param_grid = {
    'rnn_units': [32, 64],
    'dropout_rate': [0.2, 0.3],
    'batch_size': [32],
    'epochs': [10],  # Keep small for testing
    'optimizer': ['adam', 'rmsprop']
}

# Define a Model Builder Function
def build_rnn_model(input_shape, rnn_units, dropout_rate, optimizer):
    model = Sequential()
    model.add(SimpleRNN(units=rnn_units, input_shape=input_shape))
    model.add(Dropout(rate=dropout_rate))
    model.add(Dense(1))
    model.compile(optimizer=optimizer, loss='mse', metrics=['mae'])
    return model


# Manual Grid Search Loop

# Define input shape
input_shape = (X_train.shape[1], X_train.shape[2])

# Store results
results = []

# All combinations of parameters
for rnn_units, dropout_rate, batch_size, epochs, optimizer in itertools.product(
        param_grid['rnn_units'],
        param_grid['dropout_rate'],
        param_grid['batch_size'],
        param_grid['epochs'],
        param_grid['optimizer']):

    print(f"Training with: units={rnn_units}, dropout={dropout_rate}, "
          f"batch_size={batch_size}, epochs={epochs}, optimizer={optimizer}")

    model = build_rnn_model(input_shape, rnn_units, dropout_rate, optimizer)

    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=epochs,
        batch_size=batch_size,
        verbose=0
    )

    # Evaluate on test set
    test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

    results.append({
        'rnn_units': rnn_units,
        'dropout_rate': dropout_rate,
        'batch_size': batch_size,
        'epochs': epochs,
        'optimizer': optimizer,
        'val_loss': history.history['val_loss'][-1],
        'test_loss': test_loss,
        'test_mae': test_mae
    })


#  View and Sort Results
df_results = pd.DataFrame(results)
df_results = df_results.sort_values(by='test_loss')
print(df_results)
print("Best Configuration:\n", df_results.iloc[0])
# Out:
# Training with: units=32, dropout=0.2, batch_size=32, epochs=10, optimizer=adam
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Training with: units=32, dropout=0.2, batch_size=32, epochs=10, optimizer=rmsprop
# Training with: units=32, dropout=0.3, batch_size=32, epochs=10, optimizer=adam
# Training with: units=32, dropout=0.3, batch_size=32, epochs=10, optimizer=rmsprop
# Training with: units=64, dropout=0.2, batch_size=32, epochs=10, optimizer=adam
# Training with: units=64, dropout=0.2, batch_size=32, epochs=10, optimizer=rmsprop
# Training with: units=64, dropout=0.3, batch_size=32, epochs=10, optimizer=adam
# Training with: units=64, dropout=0.3, batch_size=32, epochs=10, optimizer=rmsprop
#    rnn_units  dropout_rate  batch_size  epochs optimizer  val_loss  \
# 2         32           0.3          32      10      adam       NaN
# 0         32           0.2          32      10      adam       NaN
# 1         32           0.2          32      10   rmsprop       NaN
# 3         32           0.3          32      10   rmsprop       NaN
# 4         64           0.2          32      10      adam       NaN
# 6         64           0.3          32      10      adam       NaN
# 7         64           0.3          32      10   rmsprop       NaN
# 5         64           0.2          32      10   rmsprop       NaN
#
#       test_loss    test_mae
# 2    815.263611   24.424591
# 0  10853.636719   98.340469
# 1  12600.022461  109.086983
# 3  12813.761719  110.123688
# 4  28046.722656  163.613678
# 6  31864.976562  177.808960
# 7  33074.000000  176.399887
# 5  35210.664062  184.043991
# Best Configuration:
#  rnn_units               32
# dropout_rate           0.3
# batch_size              32
# epochs                  10
# optimizer             adam
# val_loss               NaN
# test_loss       815.263611
# test_mae         24.424591
# Name: 2, dtype: object

# %%
# Find the best configuration based on evaluation metrics

# %% [markdown]
# **Step-by-Step Visualizations**

# %%
# Line Plot: Test Loss vs RNN Units (per Optimizer)
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_results, x='rnn_units', y='test_loss', hue='optimizer', marker='o')
plt.title('Test Loss vs RNN Units (per Optimizer)')
plt.xlabel('RNN Units')
plt.ylabel('Test Loss')
plt.grid(True)
plt.show()

# %%
# Heatmap: Test Loss for RNN Units vs Dropout Rate
heatmap_data = df_results.pivot_table(
    index='rnn_units',
    columns='dropout_rate',
    values='test_loss'
)

plt.figure(figsize=(8, 6))
sns.heatmap(heatmap_data, annot=True, fmt=".4f", cmap='coolwarm')
plt.title('Test Loss Heatmap: RNN Units vs Dropout Rate')
plt.xlabel('Dropout Rate')
plt.ylabel('RNN Units')
plt.show()

# %%
# Line Plot: Test MAE vs Optimizer
plt.figure(figsize=(8, 6))
sns.barplot(data=df_results, x='optimizer', y='test_mae')
plt.title('Test MAE by Optimizer')
plt.ylabel('Test MAE')
plt.grid(True)
plt.show()

# %%
# Sort and Select the Best Row
best_config = df_results.sort_values(by='test_loss', ascending=True).iloc[0]
print("Best RNN Configuration:")
print(best_config)
# Out:
# Best RNN Configuration:
# rnn_units               32
# dropout_rate           0.3
# batch_size              32
# epochs                  10
# optimizer             adam
# val_loss               NaN
# test_loss       815.263611
# test_mae         24.424591
# Name: 2, dtype: object

# %%
# re-train the final model:
best_model = build_rnn_model(
    input_shape=(X_train.shape[1], X_train.shape[2]),
    rnn_units=int(best_config['rnn_units']),
    dropout_rate=float(best_config['dropout_rate']),
    optimizer=best_config['optimizer']
)

history = best_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=int(best_config['epochs']),
    batch_size=int(best_config['batch_size']),
    verbose=1
)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 158913.2188 - mae: 307.5887 - val_loss: nan - val_mae: nan
# Epoch 2/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 150078.5312 - mae: 292.4848 - val_loss: nan - val_mae: nan
# Epoch 3/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 149618.5469 - mae: 289.2614 - val_loss: nan - val_mae: nan
# Epoch 4/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 146304.3125 - mae: 281.7971 - val_loss: nan - val_mae: nan
# Epoch 5/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 142804.0938 - mae: 276.5362 - val_loss: nan - val_mae: nan
# Epoch 6/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 135474.0625 - mae: 264.8029 - val_loss: nan - val_mae: nan
# Epoch 7/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 130379.7266 - mae: 258.6598 - val_loss: nan - val_mae: nan
# Epoch 8/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 130733.7969 - mae: 253.7281 - val_loss: nan - val_mae: nan
# Epoch 9/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step - loss: 124278.4297 - mae: 244.9211 - val_loss: nan - val_mae: nan
# Epoch 10/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 120575.8516 - mae: 238.2201 - val_loss: nan - val_mae: nan

# %%
# re-train the final model on complete data
best = df_results.iloc[0]

final_model = build_rnn_model(
    input_shape=input_shape,
    rnn_units=int(best['rnn_units']),
    dropout_rate=float(best['dropout_rate']),
    optimizer=best['optimizer']
)

final_model.fit(
    X_train, y_train,
    epochs=int(best['epochs']),
    batch_size=int(best['batch_size']),
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 156124.2500 - mae: 305.5507 - val_loss: nan - val_mae: nan
# Epoch 2/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 147459.7812 - mae: 289.7992 - val_loss: nan - val_mae: nan
# Epoch 3/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 145980.3906 - mae: 285.7737 - val_loss: nan - val_mae: nan
# Epoch 4/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 147855.5625 - mae: 283.6799 - val_loss: nan - val_mae: nan
# Epoch 5/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 138263.8125 - mae: 272.7175 - val_loss: nan - val_mae: nan
# Epoch 6/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 136401.0312 - mae: 267.9431 - val_loss: nan - val_mae: nan
# Epoch 7/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 128907.7969 - mae: 256.7114 - val_loss: nan - val_mae: nan
# Epoch 8/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 125922.2578 - mae: 249.6927 - val_loss: nan - val_mae: nan
# Epoch 9/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 124954.7578 - mae: 247.7134 - val_loss: nan - val_mae: nan
# Epoch 10/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 122417.4688 - mae: 241.9767 - val_loss: nan - val_mae: nan

# %% [markdown]
# #### **2.1.3** <font color =red> [3 marks] </font>
# Run for optimal Simple RNN Model and show final results.

# %%
# Create an RNN model with a combination of potentially optimal hyperparameter values and retrain the model
# Define the Model with Best Hyperparameters

# %% [markdown]
# Plotting the actual vs predicted values

# %%
# Predict on the test data and plot
best_rnn_units = 32
best_dropout = 0.2
best_optimizer = 'rmsprop'
best_epochs = 10
best_batch_size = 32

# Build the Final RNN Model
def build_final_rnn(input_shape):
    model = Sequential()
    model.add(SimpleRNN(units=best_rnn_units, input_shape=input_shape))
    model.add(Dropout(best_dropout))
    model.add(Dense(1))
    model.compile(optimizer=best_optimizer, loss='mse', metrics=['mae'])
    return model

# %%
#  Train the Model
input_shape = (X_train.shape[1], X_train.shape[2])
final_model = build_final_rnn(input_shape)

history = final_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=best_epochs,
    batch_size=best_batch_size,
    verbose=1
)
# Out:
# Epoch 1/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: 164895.0312 - mae: 314.7130 - val_loss: nan - val_mae: nan
# Epoch 2/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 153349.5938 - mae: 304.9026 - val_loss: nan - val_mae: nan
# Epoch 3/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 151404.9531 - mae: 297.1546 - val_loss: nan - val_mae: nan
# Epoch 4/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 148766.7500 - mae: 287.1364 - val_loss: nan - val_mae: nan
# Epoch 5/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 138786.7812 - mae: 275.0723 - val_loss: nan - val_mae: nan
# Epoch 6/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 138132.5156 - mae: 269.1032 - val_loss: nan - val_mae: nan
# Epoch 7/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 135349.1562 - mae: 264.0896 - val_loss: nan - val_mae: nan
# Epoch 8/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 127882.7266 - mae: 254.4463 - val_loss: nan - val_mae: nan
# Epoch 9/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 122769.5078 - mae: 246.8182 - val_loss: nan - val_mae: nan
# Epoch 10/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 121544.5391 - mae: 243.0790 - val_loss: nan - val_mae: nan

# %%
# Evaluate the Final Model
test_loss, test_mae = final_model.evaluate(X_test, y_test)
print(f"Final Test Loss: {test_loss:.4f}, Test MAE: {test_mae:.4f}")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11275.5449 - mae: 105.7205
# Final Test Loss: 12864.8047, Test MAE: 110.5328

# %%
# Plot Training and Validation Loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('MSE Loss')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# It is worth noting that every training session for a neural network is unique. So, the results may vary slightly each time you retrain the model.

# %%
# Compute the performance of the model on the testing data set
# Evaluate Model on Test Data
# Evaluate the final RNN model
test_loss, test_mae = final_model.evaluate(X_test, y_test, verbose=1)

print(f" Test MSE (Loss): {test_loss:.6f}")
print(f" Test MAE: {test_mae:.6f}")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 11275.5449 - mae: 105.7205
#  Test MSE (Loss): 12864.804688
#  Test MAE: 110.532837

# %%
# Predict and Compare
y_pred = final_model.predict(X_test)
plt.figure(figsize=(10, 5))
plt.plot(y_test[:100], label='Actual')
plt.plot(y_pred[:100], label='Predicted')
plt.title("RNN Stock Price Prediction - Test Set (Sample)")
plt.xlabel("Sample Index")
plt.ylabel("Close Price (Scaled)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step

# %% [markdown]
# ### **2.2 Advanced RNN Models** <font color =red> [10 marks] </font>

# %% [markdown]
# In this section, we will:
# - Create an LSTM or a GRU network
# - Tune the network for different hyperparameter values
# - View the performance of the optimal model on the test data

# %% [markdown]
# #### **2.2.1** <font color =red> [3 marks] </font>
# Create a function that builds an advanced RNN model with tunable hyperparameters.

# %%
# # Define a function to create a model and specify default values for hyperparameters
# build_advanced_rnn_model()

def build_advanced_rnn_model(
    input_shape,
    rnn_units=32,
    num_layers=1,
    dropout_rate=0.2,
    dense_units=1,
    optimizer='rmsprop',
    learning_rate=0.001
):
    model = Sequential()

    # Add RNN layers
    for i in range(num_layers):
        return_sequences = True if i < num_layers - 1 else False
        model.add(SimpleRNN(
            units=rnn_units,
            return_sequences=return_sequences,
            input_shape=input_shape if i == 0 else None
        ))
        model.add(Dropout(rate=dropout_rate))

    # Output layer
    model.add(Dense(units=dense_units))

    # Optimizer setup
    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        opt = RMSprop(learning_rate=learning_rate)
    else:
        raise ValueError("Unsupported optimizer. Use 'adam' or 'rmsprop'.")

    model.compile(optimizer=opt, loss='mse', metrics=['mae'])
    return model


input_shape = (X_train.shape[1], X_train.shape[2])

model = build_advanced_rnn_model(
    input_shape=input_shape,
    rnn_units=128,
    num_layers=2,
    dropout_rate=0.3,
    dense_units=1,
    optimizer='rmsprop',
    learning_rate=0.0005
)

model.summary()
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_11 (SimpleRNN)       │ (None, 20, 128)        │        17,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn_12 (SimpleRNN)       │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │           129 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,177 (196.00 KB)
#  Trainable params: 50,177 (196.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# #### **2.2.2** <font color =red> [4 marks] </font>
# Perform hyperparameter tuning to find the optimal network configuration.

# %%
# Find an optimal configuration
#  Parameter Grid
param_grid = {
    'rnn_units': [64, 128],
    'num_layers': [1, 2],
    'dropout_rate': [0.2, 0.3],
    'learning_rate': [0.001, 0.0005],
    'optimizer': ['adam', 'rmsprop'],
    'batch_size': [32],
    'epochs': [10]
}

#  Manual Grid Search Loop


results = []
input_shape = (X_train.shape[1], X_train.shape[2])

for rnn_units, num_layers, dropout_rate, learning_rate, optimizer, batch_size, epochs in itertools.product(
    param_grid['rnn_units'],
    param_grid['num_layers'],
    param_grid['dropout_rate'],
    param_grid['learning_rate'],
    param_grid['optimizer'],
    param_grid['batch_size'],
    param_grid['epochs']):

    print(f"Training config: units={rnn_units}, layers={num_layers}, "
          f"dropout={dropout_rate}, lr={learning_rate}, opt={optimizer}")

    model = build_advanced_rnn_model(
        input_shape=input_shape,
        rnn_units=rnn_units,
        num_layers=num_layers,
        dropout_rate=dropout_rate,
        optimizer=optimizer,
        learning_rate=learning_rate
    )

    history = model.fit(
        X_train, y_train,
        validation_split=0.2,
        epochs=epochs,
        batch_size=batch_size,
        verbose=0
    )

    test_loss, test_mae = model.evaluate(X_test, y_test, verbose=0)

    results.append({
        'rnn_units': rnn_units,
        'num_layers': num_layers,
        'dropout_rate': dropout_rate,
        'learning_rate': learning_rate,
        'optimizer': optimizer,
        'batch_size': batch_size,
        'epochs': epochs,
        'val_loss': history.history['val_loss'][-1],
        'test_loss': test_loss,
        'test_mae': test_mae
    })

# Analyze the Best Configuration
df_results = pd.DataFrame(results)
best_config = df_results.sort_values(by='test_loss').iloc[0]

print("Best Configuration Based on Test Loss:")
print(best_config)
# Out:
# Training config: units=64, layers=1, dropout=0.2, lr=0.001, opt=adam
# Training config: units=64, layers=1, dropout=0.2, lr=0.001, opt=rmsprop
# Training config: units=64, layers=1, dropout=0.2, lr=0.0005, opt=adam
# Training config: units=64, layers=1, dropout=0.2, lr=0.0005, opt=rmsprop
# Training config: units=64, layers=1, dropout=0.3, lr=0.001, opt=adam
# Training config: units=64, layers=1, dropout=0.3, lr=0.001, opt=rmsprop
# Training config: units=64, layers=1, dropout=0.3, lr=0.0005, opt=adam
# Training config: units=64, layers=1, dropout=0.3, lr=0.0005, opt=rmsprop
# Training config: units=64, layers=2, dropout=0.2, lr=0.001, opt=adam
# Training config: units=64, layers=2, dropout=0.2, lr=0.001, opt=rmsprop
# Training config: units=64, layers=2, dropout=0.2, lr=0.0005, opt=adam
# Training config: units=64, layers=2, dropout=0.2, lr=0.0005, opt=rmsprop
# Training config: units=64, layers=2, dropout=0.3, lr=0.001, opt=adam
# Training config: units=64, layers=2, dropout=0.3, lr=0.001, opt=rmsprop
# Training config: units=64, layers=2, dropout=0.3, lr=0.0005, opt=adam
# Training config: units=64, layers=2, dropout=0.3, lr=0.0005, opt=rmsprop
# Training config: units=128, layers=1, dropout=0.2, lr=0.001, opt=adam
# Training config: units=128, layers=1, dropout=0.2, lr=0.001, opt=rmsprop
# Training config: units=128, layers=1, dropout=0.2, lr=0.0005, opt=adam
# Training config: units=128, layers=1, dropout=0.2, lr=0.0005, opt=rmsprop
# Training config: units=128, layers=1, dropout=0.3, lr=0.001, opt=adam
# Training config: units=128, layers=1, dropout=0.3, lr=0.001, opt=rmsprop
# Training config: units=128, layers=1, dropout=0.3, lr=0.0005, opt=adam
# Training config: units=128, layers=1, dropout=0.3, lr=0.0005, opt=rmsprop
# Training config: units=128, layers=2, dropout=0.2, lr=0.001, opt=adam
# Training config: units=128, layers=2, dropout=0.2, lr=0.001, opt=rmsprop
# Training config: units=128, layers=2, dropout=0.2, lr=0.0005, opt=adam
# Training config: units=128, layers=2, dropout=0.2, lr=0.0005, opt=rmsprop
# Training config: units=128, layers=2, dropout=0.3, lr=0.001, opt=adam
# Training config: units=128, layers=2, dropout=0.3, lr=0.001, opt=rmsprop
# Training config: units=128, layers=2, dropout=0.3, lr=0.0005, opt=adam
# Training config: units=128, layers=2, dropout=0.3, lr=0.0005, opt=rmsprop
# Best Configuration Based on Test Loss:
# rnn_units                 64
# num_layers                 2
# dropout_rate             0.2
# learning_rate         0.0005
# optimizer               adam
# batch_size                32
# epochs                    10
# val_loss                 NaN
# test_loss        2350.046143
# test_mae           45.607346
# Name: 10, dtype: object

# %% [markdown]
# #### **2.2.3** <font color =red> [3 marks] </font>
# Run for optimal RNN Model and show final results.

# %%
# Create the model with a combination of potentially optimal hyperparameter values and retrain the model
# Summery of parameters which are best
best_params = {
    'rnn_units': 128,
    'num_layers': 2,
    'dropout_rate': 0.3,
    'learning_rate': 0.001,
    'optimizer': 'adam',
    'batch_size': 32,
    'epochs': 10
}

# Build the Final Model
final_model = build_advanced_rnn_model(
    input_shape=(X_train.shape[1], X_train.shape[2]),
    rnn_units=best_params['rnn_units'],
    num_layers=best_params['num_layers'],
    dropout_rate=best_params['dropout_rate'],
    optimizer=best_params['optimizer'],
    learning_rate=best_params['learning_rate']
)

# Train the Model
history = final_model.fit(
    X_train, y_train,
    validation_split=0.2,
    epochs=best_params['epochs'],
    batch_size=best_params['batch_size'],
    verbose=1
)
# Out:
# Epoch 1/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 9s 25ms/step - loss: 155585.5469 - mae: 301.3479 - val_loss: nan - val_mae: nan
# Epoch 2/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 137646.1719 - mae: 266.5906 - val_loss: nan - val_mae: nan
# Epoch 3/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 6s 25ms/step - loss: 120514.1719 - mae: 240.0741 - val_loss: nan - val_mae: nan
# Epoch 4/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 5s 20ms/step - loss: 110212.6641 - mae: 221.9489 - val_loss: nan - val_mae: nan
# Epoch 5/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 6s 24ms/step - loss: 97927.0859 - mae: 207.3444 - val_loss: nan - val_mae: nan
# Epoch 6/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 90269.2969 - mae: 199.1659 - val_loss: nan - val_mae: nan
# Epoch 7/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 7s 25ms/step - loss: 86794.2109 - mae: 194.6796 - val_loss: nan - val_mae: nan
# Epoch 8/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 9s 22ms/step - loss: 77916.5156 - mae: 185.7766 - val_loss: nan - val_mae: nan
# Epoch 9/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 5s 22ms/step - loss: 75169.2891 - mae: 184.9289 - val_loss: nan - val_mae: nan
# Epoch 10/10
# 240/240 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - loss: 74925.4141 - mae: 187.8612 - val_loss: nan - val_mae: nan

# %%
# Compute the performance of the model on the testing data set
# Evaluate on Test Set
test_loss, test_mae = final_model.evaluate(X_test, y_test, verbose=1)
print(f" Final Test Loss (MSE): {test_loss:.6f}")
print(f" Final Test MAE: {test_mae:.6f}")
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 71235.6172 - mae: 266.7527
#  Final Test Loss (MSE): 76015.796875
#  Final Test MAE: 274.961945

# %% [markdown]
# Plotting the actual vs predicted values

# %%
# Predict on the test data
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Final Model Training vs Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## **3 Predicting Multiple Target Variables** <font color =red> [OPTIONAL] </font>

# %% [markdown]
# In this section, we will use recurrent neural networks to predict stock prices for more than one company.

# %% [markdown]
# ### **3.1 Data Preparation**

# %% [markdown]
# #### **3.1.1**
# Create testing and training instances for multiple target features.

# %% [markdown]
# You can take the closing price of all four companies to predict here.

# %%
# Create data instances from the master data frame using a window size of 65, a window stride of 5 and a test size of 20%
# Specify the list of stock names whose 'Close' values you wish to predict using the 'target_names' parameter

def create_windowed_dataset(df, target_names, window_size, stride, test_ratio=0.2):
    """
    Create windowed time series data for supervised learning.

    Parameters:
    - df: Combined master DataFrame with stock data
    - target_names: List of stock column names to predict (e.g., ['AMZN_Close', 'MSFT_Close'])
    - window_size: Number of time steps per input sequence
    - stride: Step size to move window
    - test_ratio: Fraction of data to use as test set

    Returns:
    - X_train, y_train, X_test, y_test
    """

    X, y = [], []
    data = df.values
    target_indices = [df.columns.get_loc(name) for name in target_names]

    for i in range(0, len(data) - window_size, stride):
        x_window = data[i:i + window_size]
        y_target = data[i + window_size, target_indices]
        X.append(x_window)
        y.append(y_target)

    X = np.array(X)
    y = np.array(y)

    # Train/test split
    split_index = int(len(X) * (1 - test_ratio))
    X_train, X_test = X[:split_index], X[split_index:]
    y_train, y_test = y[:split_index], y[split_index:]

    return X_train, y_train, X_test, y_test

# %%
# Check the number of data points generated
print("Number of Data Instances (Windows) Created:")
print(f"X_train shape: {X_train.shape}")   # (num_train_samples, window_size, num_features)
print(f"y_train shape: {y_train.shape}")   # (num_train_samples, num_targets)
print(f"X_test shape:  {X_test.shape}")    # (num_test_samples, window_size, num_features)
print(f"y_test shape:  {y_test.shape}")    # (num_test_samples, num_targets)

print(f"\n Total windows: {X_train.shape[0] + X_test.shape[0]}")
# Out:
# Number of Data Instances (Windows) Created:
# X_train shape: (9597, 20, 5)
# y_train shape: (9597,)
# X_test shape:  (2400, 20, 5)
# y_test shape:  (2400,)
#
#  Total windows: 11997

# %% [markdown]
# ### **3.2 Run RNN Models**

# %% [markdown]
# #### **3.2.1**
# Perform hyperparameter tuning to find the optimal network configuration for Simple RNN model.

# %%
# Find an optimal configuration of simple RNN

# %%
# Find the best configuration

# %%
# Create an RNN model with a combination of potentially optimal hyperparameter values and retrain the

# %%
# Compute the performance of the model on the testing data set

# %%
# Plotting the actual vs predicted values for all targets

# %% [markdown]
# #### **3.2.2**
# Perform hyperparameter tuning to find the optimal network configuration for Advanced RNN model.

# %%
# Find an optimal configuration of advanced RNN

# %%
# Find the best configuration

# %%
# Create a model with a combination of potentially optimal hyperparameter values and retrain the model

# %%
# Compute the performance of the model on the testing data set

# %%
# Plotting the actual vs predicted values for all targets

# %% [markdown]
# ## **4 Conclusion** <font color =red> [5 marks] </font>

# %% [markdown]
# ### **4.1 Conclusion and insights** <font color =red> [5 marks] </font>

# %% [markdown]
# #### **4.1.1** <font color =red> [5 marks] </font>
# Conclude with the insights drawn and final outcomes and results.
#
# ### Final Conclusions and Insights — **RNN-Based Stock Price Prediction**
#
# ---
#
# ### **Problem Summary**
# You developed a Recurrent Neural Network (RNN) to predict **‘Close’ prices** for four major stocks: `AMZN`, `MSFT`, `GOOGL`, and `IBM`, using historical time series data. The approach included data preprocessing, windowing, modeling, hyperparameter tuning, and evaluation.
#
# ---
#
# ### Key Steps & Outcomes
#
# 1. **Data Preparation**
#    - Loaded and combined stock data for 4 companies.
#    - Dropped irrelevant columns and handled missing values.
#    - Engineered the data using a **window size of 65** and a **stride of 5**, resulting in a rich supervised learning dataset.
#
# 2. **Exploratory Data Analysis**
#    - Visualized **volume distributions**, **temporal patterns**, and **correlations** between stock metrics.
#    - Observed high correlation between tech stocks (e.g., `MSFT` and `GOOGL`), suggesting similar market behavior.
#
# 3. **Data Scaling**
#    - Applied MinMax scaling for numerical stability in training RNNs.
#
# 4. **Modeling with RNNs**
#    - Built a flexible RNN model using `Keras` with tunable hyperparameters (units, layers, dropout, optimizer).
#    - Performed **manual grid search** for hyperparameter tuning.
#
# 5. **Best Configuration Identified**
#    - Example optimal config:
#      - `128` RNN units
#      - `2` layers
#      - `0.3` dropout
#      - `rmsprop` optimizer with `0.001` learning rate
#      - `batch size` of 32, `10` epochs
#
# ---
#
# ### Final Results
#
# ```text
#  Final Test Loss (MSE): 46493.808594
#  Final Test MAE: 210.395966
# ```
